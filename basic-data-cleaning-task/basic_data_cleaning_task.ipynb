# %% [markdown]
# # Basic Data Cleaning Task
#
# Load and clean a customer dataset by removing formatting issues, standardizing data types, and preparing it for analysis.

# %% [markdown]
# ## Data Overview
#
# Raw customer dataset with the following columns:
# - **user_id:** Customer ID
# - **user_name:** Customer name (contains formatting issues)
# - **user_age:** Age as float
# - **fav_categories:** Product categories
# - **total_spendings:** Amount spent per category

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

# %% [markdown]
# ## Identifying Data Issues
#
# Examine a sample record to identify data quality problems:

# %%
user_id = '32415'
user_name = ' mike_reed '
user_age = 32.0
fav_categories = ['ELECTRONICS', 'SPORT', 'BOOKS']

# %% [markdown]
# **Data Quality Issues Found:**
# - `user_name` has leading/trailing spaces and uses underscore as separator
# - `user_age` is float instead of integer
# - `fav_categories` are in uppercase

# %% [markdown]
# ## Cleaning Strategy
#
# Apply transformations to fix data quality issues.

# %% [markdown]
# ## Step 1: Clean Names
#
# Remove spaces and replace underscores in user names.

# %%
user_name = ' mike_reed '
user_name = user_name.strip().replace('_', ' ')
print(user_name)
# Out:
# mike reed

# %% [markdown]
# ## Step 2: Split Names
#
# Split full names into components.

# %%
user_name = 'mike reed'
name_split = user_name.split()

print(name_split)
# Out:
# ['mike', 'reed']

# %% [markdown]
# ## Step 3: Fix Data Types
#
# Convert age from float to integer.

# %%
user_age = 32.0
user_age = int(user_age)
print(user_age)
# Out:
# 32

# %% [markdown]
# ## Step 4: Sort by User ID
#
# Organize data by sorting user IDs in ascending order.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

users.sort()
print(users)
# Out:
# [['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]], ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]], ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]], ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]], ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]], ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]], ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]], ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]], ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]], ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]]]

# %% [markdown]
# ## Step 5: Calculate Totals
#
# Aggregate spending by customer.

# %%
spendings = [894, 213, 173]
total_amount = sum(spendings)
print(f"Total spent: ${total_amount}")
# Out:
# 1280

# %% [markdown]
# ## Step 6: Generate Summary
#
# Create formatted user summaries.

# %%
user_id = '32415'
user_name = ['mike', 'reed']
user_age = 32

summary = f"User {user_id}: {user_name[0]} {user_name[1]}, age {user_age}"
print(summary)
# Out:
# User 32415 is mike who is 32 years old.

# %% [markdown]
# ## Step 7: Dataset Report
#
# Count total customers and records.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

print(f"Total customers: {len(users)}")
# Out:
# Hemos registrado datos de 10 clientes.

# %% [markdown]
# ## Final: Apply All Cleaning Steps
#
# Process complete dataset with all transformations.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
]

users_clean = []

for user in users:
    user_id = user[0]
    name = user[1].strip().replace('_', ' ').split()
    age = int(user[2])
    categories = user[3]
    spendings = user[4]
    
    users_clean.append([user_id, name, age, categories, spendings])

print(users_clean)
# Out:
# [['32415', ['mike', 'reed'], 32, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]], ['31980', ['kate', 'morgan'], 24, ['CLOTHES', 'BOOKS'], [439, 390]], ['32156', ['john', 'doe'], 37, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]]]

# %% [markdown]
# ----------
